# %% [markdown]
# # Molecular Discovery с GRA-SubjectSwap
# ИИ-агент ставит цели синтеза, человек-лаборант — инструмент с чёткими инструкциями.

# %%
from src.core import Swarm, Agent, Human
chemist = Human('chemist')
ai = Agent('ai', ['director', 'analyzer'])
# ...
